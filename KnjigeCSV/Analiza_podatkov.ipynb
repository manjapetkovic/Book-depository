# %%
# %matplotlib inline
import pandas as pd
pd.options.display.max_rows = 25
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5f258c04017c> in <module>()
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import pandas as pd
#       3 pd.options.display.max_rows = 20
#
# c:\users\manja\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2093                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2094             with self.builtin_trap:
# -> 2095                 result = fn(*args,**kwargs)
#    2096             return result
#    2097
#
# <decorator-gen-108> in matplotlib(self, line)
#
# c:\users\manja\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\users\manja\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# c:\users\manja\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    2964         """
#    2965         from IPython.core import pylabtools as pt
# -> 2966         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2967
#    2968         if gui != 'inline':
#
# c:\users\manja\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\pylabtools.py in find_gui_and_backend(gui, gui_select)
#     268     """
#     269
# --> 270     import matplotlib
#     271
#     272     if gui and gui != 'auto':
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# # Najbolj popularne knjige na Book depository

# %% [markdown]
# V projektno nalogo sem zajela podatke 1000 najbol prodajanih knjig na spletni strani http://www.bookdepository.com/bestsellers?format=1,2&searchLang=123. Omejila sem se zgolj na knjiged v angleškem jeziku, iz seznama sem izvzela eletronske knjige, ter turistične vodiče. Zbirala sem podatke o uvrstitvi, avtorju, naslovu, mesecu izdaje, letu izdaje ter formatu knjige.

# %% [markdown]
# Za začetek si poglejmo tabelo z vsemi zbranimi podatki

# %%
knjige=pd.read_csv('podatki.csv')
knjige
# Out:
#       uvrstitev                          avtor  \
# 0             1                     Scott Pape
# 1             2                    Mark Manson
# 2             3                   Jamie Oliver
# 3             4                      Rupi Kaur
# 4             5                  Elena Favilli
# 5             6                   Andre Aciman
# 6             7              Yuval Noah Harari
# 7             8                  R. J. Palacio
# 8             9           Dr. Patrizia Collard
# 9            10                 Paul Kalanithi
# ...         ...                            ...
# 1005       1085                   Noam Chomsky
# 1006       1086  General Stanley A. McChrystal
# 1007       1087            William Shakespeare
# 1008       1088                  Adam J. Kurtz
# 1009       1090                 Irvin D. Yalom
# 1010       1091                 Philip Pullman
# 1011       1092                  Carlo Rovelli
# 1012       1093                     John Yorke
# 1013       1094                   Mary Shelley
# 1014       1095                   Rick Riordan
#
#                                               naslov mesec_izdaje  \
# 0                              The Barefoot Investor          Jul
# 1                The Subtle Art of Not Giving a F*ck          Sep
# 2              5 Ingredients - Quick &amp; Easy Food          Sep
# 3                                     Milk and Honey          Sep
# 4                 Good Night Stories for Rebel Girls          Mar
# 5                               Call Me By Your Name          Sep
# 6                                            Sapiens          Sep
# 7                                             Wonder          Mar
# 8                     The Little Book of Mindfulness          May
# 9                            When Breath Becomes Air          Jan
# ...                                              ...          ...
# 1005                            Who Rules the World?          Apr
# 1006                                   Team of Teams          Nov
# 1007     Oxford School Shakespeare: Romeo and Juliet          Apr
# 1008                Things Are What You Make of Them          Oct
# 1009                         Love&#039;s Executioner          Jul
# 1010                                     Grimm Tales          Sep
# 1011                  Seven Brief Lessons on Physics          Jul
# 1012                                  Into The Woods          Oct
# 1013                                    Frankenstein          May
# 1014  Percy Jackson and the Sea of Monsters (Book 2)          Jul
#
#       leto_izdaje     format
# 0            2017  Paperback
# 1            2016   Hardback
# 2            2017   Hardback
# 3            2017  Paperback
# 4            2017   Hardback
# 5            2017  Paperback
# 6            2016  Paperback
# 7            2013  Paperback
# 8            2014  Paperback
# 9            2017  Paperback
# ...           ...        ...
# 1005         2017  Paperback
# 1006         2015  Paperback
# 1007         2009  Paperback
# 1008         2017  Paperback
# 1009         2015  Paperback
# 1010         2013  Paperback
# 1011         2016  Paperback
# 1012         2015  Paperback
# 1013         2003  Paperback
# 1014         2013  Paperback
#
# [1015 rows x 6 columns]

# %% [markdown]
# Poglejmo si v katerem letu je bilo izdanih največ knjig iz seznama. Podatki kažejo, da so trenutno najpopularnejše knjige izdane po letu 2010, kar ni presenetljivo.

# %%
#v katerem letu je bilo izdanih največ knjig iz seznama
knjige_po_letih=knjige.groupby('leto_izdaje').size().plot()

# %% [markdown]
# Naslednji graf prikazuje 20 najpogostejših avtorjev na seznamu. Očitno je najbolša avtorjica J.K.Rowlong, ki je izdala zbirko sedmih knjig o mladem čarovniku Harry Pottru.

# %%
#najboljših 20 avtorjev
avtor=knjige['avtor'].value_counts().head(20)
avtor

# %% [markdown]
# Oglejmo si knjige, ki pripadajo najboljši avtorici:

# %%
#razpredelnica knjig najpogostejše avtorice
najpogostejsa_avtorica=knjige[knjige['avtor'] == "J. K. Rowling"]
najpogostejsa_avtorica
# Out:
#      uvrstitev          avtor  \
# 11          12  J. K. Rowling
# 30          33  J. K. Rowling
# 38          42  J. K. Rowling
# 88          96  J. K. Rowling
# 150        160  J. K. Rowling
# 166        179  J. K. Rowling
# 192        207  J. K. Rowling
# 217        234  J. K. Rowling
# 277        299  J. K. Rowling
# 356        388  J. K. Rowling
# ..         ...            ...
# 438        475  J. K. Rowling
# 439        476  J. K. Rowling
# 459        498  J. K. Rowling
# 496        536  J. K. Rowling
# 625        676  J. K. Rowling
# 626        677  J. K. Rowling
# 677        729  J. K. Rowling
# 886        955  J. K. Rowling
# 887        956  J. K. Rowling
# 969       1047  J. K. Rowling
#
#                                                 naslov mesec_izdaje  \
# 11       Harry Potter and the Philosopher&#039;s Stone          Oct
# 30            Harry Potter and the Prisoner of Azkaban          Nov
# 38             Harry Potter and the Chamber of Secrets          Oct
# 88   Harry Potter Box Set: The Complete Collection ...          Oct
# 150            Fantastic Beasts and Where to Find Them          Nov
# 166  Harry Potter and the Philosopher&#039;s Stone ...          Jun
# 192  Harry Potter and the Philosopher&#039;s Stone ...          Jun
# 217  Harry Potter and the Cursed Child - Parts One ...          Jul
# 277      Harry Potter and the Philosopher&#039;s Stone          Oct
# 356  Harry Potter and the Philosopher&#039;s Stone ...          Jun
# ..                                                 ...          ...
# 438           Harry Potter and the Prisoner of Azkaban          Oct
# 439  Harry Potter Boxed Set: The Complete Collectio...          Nov
# 459               Harry Potter and the Deathly Hallows          Oct
# 496            Harry Potter and the Chamber of Secrets          Oct
# 625          Harry Potter and the Order of the Phoenix          Oct
# 626                Harry Potter and the Goblet of Fire          Oct
# 677            Fantastic Beasts and Where to Find Them          Nov
# 886             Harry Potter and the Half-Blood Prince          Oct
# 887  Harry Potter and the Philosopher&#039;s Stone ...          Jun
# 969  Harry Potter and the Philosopher&#039;s Stone ...          Jun
#
#      leto_izdaje     format
# 11          2015   Hardback
# 30          2017   Hardback
# 38          2016   Hardback
# 88          2014  Paperback
# 150         2017   Hardback
# 166         2017   Hardback
# 192         2017   Hardback
# 217         2017  Paperback
# 277         2014  Paperback
# 356         2017   Hardback
# ..           ...        ...
# 438         2014  Paperback
# 439         2013  Paperback
# 459         2014  Paperback
# 496         2014  Paperback
# 625         2014  Paperback
# 626         2014  Paperback
# 677         2016   Hardback
# 886         2014  Paperback
# 887         2017  Paperback
# 969         2017  Paperback
#
# [23 rows x 6 columns]

# %%
najpogostejsa_avtorica[['naslov', 'leto_izdaje']].sort_values('leto_izdaje')
# Out:
#                                                 naslov  leto_izdaje
# 420                       The Tales of Beedle the Bard         2008
# 439  Harry Potter Boxed Set: The Complete Collectio...         2013
# 414  Harry Potter Box Set: The Complete Collection ...         2014
# 886             Harry Potter and the Half-Blood Prince         2014
# 626                Harry Potter and the Goblet of Fire         2014
# 88   Harry Potter Box Set: The Complete Collection ...         2014
# 625          Harry Potter and the Order of the Phoenix         2014
# 496            Harry Potter and the Chamber of Secrets         2014
# 459               Harry Potter and the Deathly Hallows         2014
# 277      Harry Potter and the Philosopher&#039;s Stone         2014
# ..                                                 ...          ...
# 677            Fantastic Beasts and Where to Find Them         2016
# 373  Harry Potter and the Philosopher&#039;s Stone ...         2017
# 356  Harry Potter and the Philosopher&#039;s Stone ...         2017
# 217  Harry Potter and the Cursed Child - Parts One ...         2017
# 192  Harry Potter and the Philosopher&#039;s Stone ...         2017
# 166  Harry Potter and the Philosopher&#039;s Stone ...         2017
# 150            Fantastic Beasts and Where to Find Them         2017
# 30            Harry Potter and the Prisoner of Azkaban         2017
# 887  Harry Potter and the Philosopher&#039;s Stone ...         2017
# 969  Harry Potter and the Philosopher&#039;s Stone ...         2017
#
# [23 rows x 2 columns]

# %% [markdown]
# Kot vidimo je saga o Harry Pottru res popularna, saj je avtorica po njen izdala še nekaj knjig, ki pa očitno niso tako uspešne.

# %% [markdown]
# Poglejmo si še kater format je bolj priljubljen. Kot vidimo so knjige z mehkimi platnicami veliko bolj popularne, kar spet ni presenetljivo ker so te knjige po navadi lažje za izdelavo ter zato cenejše pa tudi bolj praktične. V nadaljevanju si bomo podrobneje poglejmo nekaj podatkov o vsakem formatu.

# %%
#delež knjig s trdimi in mehkimi platnicami
vrsta_platnice=knjige['format'].value_counts().plot(kind='pie')

# %% [markdown]
# Spodnja tabela prikazuje knjige s trdimi platnicami urejene glede na leto izdaje. Vidimo zanimiv podatek, da je bila najstarejša knjiga iz seznama izdana šele leta 2001. Ta podatek se mi zdi presnetljiv, bi pričakovala, da bodo starejše knjige izdane v trdi vezavi, novejše pa v mehki.

# %%
#knjige s trdimi platnicami 
trde_platnice=knjige[knjige['format'] == "Hardback"].sort_values('leto_izdaje')
trde_platnice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2dca04a4edac> in <module>()
#       1 #knjige s trdimi platnicami
# ----> 2 trde_platnice=knjige[knjige['format'] == "Hardback"].sort_values('leto_izdaje')
#       3 trde_platnice
#
# NameError: name 'knjige' is not defined

# %% [markdown]
# Pa poglejmo še mehke platnice. Glede na to, da je knjig z mehkimi platnicami veliko več, me je zanimalo, ali ima tudi tukaj J.K. Rowling takšno prednost pred ostalimi. Očitno ji sledi Brandon Sanderson, ki ravno tako kot prej omenjena avtorica piše knjige znanstveno fantastiko.

# %%
#najboljši avtorji knjig z mehkimi platnicami
mehke_platnice=knjige[knjige['format'] == "Paperback"]
avtorji_mehke_platnce=mehke_platnice['avtor'].value_counts().head(20).plot.bar()

# %% [markdown]
# Pred nami je graf s povprečnimi uvrstitvami knjig z mehkimi platnicami po letih. Zanimalo me je, ali so knjige iz določenega obdobja še visoko uvrščene, vendar graf prikazuje, da nobeno leto posebno ne izstopa.

# %%
#povprečna uvrstitev knjig z mehkimi platnicami
povprecna_uvrstitev=mehke_platnice.groupby('leto_izdaje')
povprecna_uvrstitev['uvrstitev'].mean()
# Out:
# leto_izdaje
# 1969     907.000000
# 1982     539.000000
# 1986     284.000000
# 1991     671.666667
# 1992     432.000000
# 1994     883.666667
# 1995     645.000000
# 1996    1076.000000
# 1997     668.285714
# 1998     592.400000
#            ...
# 2009     559.900000
# 2010     615.384615
# 2011     591.911111
# 2012     468.714286
# 2013     664.029412
# 2014     545.474576
# 2015     578.577320
# 2016     580.377193
# 2017     539.489083
# 2018     500.600000
# Name: uvrstitev, Length: 30, dtype: float64

# %% [markdown]
# Pa pojdimo še malo v zgodovino. Spodaj imamo tabelo s knjigami, ki so nastale pred letom 2000 razvrščene glede na uvrstitev. Vidimo da jih ni ravno veliko...... DOKONČAJ

# %%
#razpredelnica knjig izdanih pred letom 2000
knjige_20_stoletja=knjige[knjige.leto_izdaje < 2000]
knjige_20_stoletja.sort_values('uvrstitev')
# Out:
#      uvrstitev                     avtor  \
# 229        247       F. Scott Fitzgerald
# 243        262       Arthur Edward Waite
# 423        459            Dalai Lama XIV
# 542        586         William I. Strunk
# 43          47  Antoine de Saint-Exupery
# 827        893           Richard Carlson
# 421        457              Timothy Zahn
# 806        871             9780850364781
# 642        694              S. E. Hinton
# 136        146           Don Miguel Ruiz
# ..         ...                       ...
# 545        589          Ernest Hemingway
# 924        997          Ernest Hemingway
# 986       1065            Willard Palmer
# 397        432       Niccolo Machiavelli
# 640        692                   Mem Fox
# 399        434             Kurt Vonnegut
# 823        889           Joseph Campbell
# 264        284             Robert Munsch
# 499        539              Helene Hanff
# 841        907     Lucius Annaeus Seneca
#
#                                                 naslov mesec_izdaje  \
# 229                                   The Great Gatsby          Dec
# 243                The Original Rider Waite Tarot Deck          Jun
# 423                               The Art of Happiness          Nov
# 542                              The Elements of Style          Aug
# 43                                   The Little Prince          Jan
# 827                   Don&#039;t Sweat the Small Stuff          May
# 421                                       Star Wars 01          Nov
# 806                          Redstone Diary 2018: Play          Jan
# 642                                      The Outsiders          Dec
# 136                                The Four Agreements          Nov
# ..                                                 ...          ...
# 545                            The Old Man and the Sea          Aug
# 924                                             Fiesta          Aug
# 986  The Complete Book of Scales, Chords, Arpeggios...          Aug
# 397                                         The Prince          Sep
# 640                                       Possum Magic          Sep
# 399                                   Slaughterhouse 5          Mar
# 823                                      Power of Myth          Jul
# 264                             The Paper Bag Princess          Dec
# 499                              84 Charing Cross Road          Sep
# 841                               Letters from a Stoic          Jul
#
#      leto_izdaje     format
# 229         1999  Paperback
# 243         1999  Paperback
# 423         1999  Paperback
# 542         1999  Paperback
# 43          1998  Paperback
# 827         1998  Paperback
# 421         1998  Paperback
# 806         1998  Paperback
# 642         1998  Paperback
# 136         1997  Paperback
# ..           ...        ...
# 545         1994  Paperback
# 924         1994  Paperback
# 986         1994  Paperback
# 397         1992  Paperback
# 640         1991  Paperback
# 399         1991  Paperback
# 823         1991  Paperback
# 264         1986  Paperback
# 499         1982  Paperback
# 841         1969  Paperback
#
# [31 rows x 6 columns]

# %% [markdown]
# Poglejmo si najpopularnejše avtorje takrat izdanih knjig. DOKONČAJ

# %%
#avtorji pred letom 2000
knjige_2000=knjige[knjige.leto_izdaje < 2000]
avtorji_po_2000=knjige_2000['avtor'].value_counts().head(10).plot.bar()

# %% [markdown]
# Za konec si oglejmo še v katgerih mesecih je bilo izdanih največ knjig. Kot je razvidno iz grafa je najbol ugodno obdobje za izdajo knjig jesen.

# %%
#v katerem mesecu je bilo izdanih največ knjig
ugoden_mesec=knjige['mesec_izdaje'].value_counts().plot.bar()
